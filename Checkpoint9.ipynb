# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynebgh/CKPT1/blob/main/Checkpoint9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/Market_Basket_Optimisation.csv", header = None)
df
# Out:
#                  0                  1   ...       18         19
# 0            shrimp            almonds  ...  spinach  olive oil
# 1           burgers          meatballs  ...      NaN        NaN
# 2           chutney                NaN  ...      NaN        NaN
# 3            turkey            avocado  ...      NaN        NaN
# 4     mineral water               milk  ...      NaN        NaN
# ...             ...                ...  ...      ...        ...
# 7496         butter         light mayo  ...      NaN        NaN
# 7497        burgers  frozen vegetables  ...      NaN        NaN
# 7498        chicken                NaN  ...      NaN        NaN
# 7499       escalope          green tea  ...      NaN        NaN
# 7500           eggs    frozen smoothie  ...      NaN        NaN
#
# [7501 rows x 20 columns]

# %%
df.fillna('',axis=1,inplace=True)
df
# Out:
#                  0                  1   ...       18         19
# 0            shrimp            almonds  ...  spinach  olive oil
# 1           burgers          meatballs  ...
# 2           chutney                     ...
# 3            turkey            avocado  ...
# 4     mineral water               milk  ...
# ...             ...                ...  ...      ...        ...
# 7496         butter         light mayo  ...
# 7497        burgers  frozen vegetables  ...
# 7498        chicken                     ...
# 7499       escalope          green tea  ...
# 7500           eggs    frozen smoothie  ...
#
# [7501 rows x 20 columns]

# %%
df_list = df.to_numpy().tolist()
df_list
dataset = list()
for i in range(len(df_list)) :
    item = list()
    for j in df_list[i] :
        if pd.notna(j):
            item.append(j)
    dataset.append(item)
dataset[0]
# Out:
# ['shrimp',
#  'almonds',
#  'avocado',
#  'vegetables mix',
#  'green grapes',
#  'whole weat flour',
#  'yams',
#  'cottage cheese',
#  'energy drink',
#  'tomato juice',
#  'low fat yogurt',
#  'green tea',
#  'honey',
#  'salad',
#  'mineral water',
#  'salmon',
#  'antioxydant juice',
#  'frozen smoothie',
#  'spinach',
#  'olive oil']

# %%
import mlxtend
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_array = te.fit(dataset).transform(dataset)
te_array
final_df = pd.DataFrame(te_array,columns=te.columns_)
final_df.drop(columns=[''],axis=1,inplace=True)
final_df
# Out:
#        asparagus  almonds  antioxydant juice  ...   yams  yogurt cake  zucchini
# 0          False     True               True  ...   True        False     False
# 1          False    False              False  ...  False        False     False
# 2          False    False              False  ...  False        False     False
# 3          False    False              False  ...  False        False     False
# 4          False    False              False  ...  False        False     False
# ...          ...      ...                ...  ...    ...          ...       ...
# 7496       False    False              False  ...  False        False     False
# 7497       False    False              False  ...  False        False     False
# 7498       False    False              False  ...  False        False     False
# 7499       False    False              False  ...  False        False     False
# 7500       False    False              False  ...  False         True     False
#
# ...

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(final_df, min_support = 0.01, use_colnames = True)
frequent_itemsets
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (milk, mineral water, ground beef)
# 253  0.017064  (mineral water, ground beef, spaghetti)
# 254  0.015731         (milk, mineral water, spaghetti)
# 255  0.010265    (mineral water, olive oil, spaghetti)
# 256  0.011465     (pancakes, mineral water, spaghetti)
#
# [257 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules
rules_ap = association_rules(frequent_itemsets, metric = "confidence", min_threshold = .2)
result = pd.DataFrame(rules_ap)
result.sort_values(by="lift", inplace = True, ascending = False)
result
# Out:
#                     antecedents          consequents  ...  leverage  conviction
# 75              (herb & pepper)        (ground beef)  ...  0.011138    1.332860
# 153  (mineral water, spaghetti)        (ground beef)  ...  0.011196    1.262445
# 69                   (tomatoes)  (frozen vegetables)  ...  0.009612    1.183930
# 67                     (shrimp)  (frozen vegetables)  ...  0.009853    1.179825
# 143       (milk, mineral water)  (frozen vegetables)  ...  0.006490    1.175757
# ..                          ...                  ...  ...       ...         ...
# 74                  (green tea)          (spaghetti)  ...  0.003527    1.033405
# 46                (ground beef)               (eggs)  ...  0.002340    1.029905
# 19                  (chocolate)               (eggs)  ...  0.003751    1.028711
# 73                  (green tea)      (mineral water)  ... -0.000430    0.995748
# 57                   (escalope)      (mineral water)  ... -0.001844    0.970387
#
# ...
