# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynebgh/CKPT1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
plt.style.use('ggplot')
df = pd.read_csv('/content/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
df["Outcome"].value_counts().plot(kind="bar",color=["red","yellow"])

# %%
sns.boxplot(data=df, x='Outcome', y='Age')

# %%
df.Age.plot.hist();

# %%
grid = sns.FacetGrid(df, col="Insulin", size=2.2, aspect=1.6)
grid.map(sns.countplot, "Outcome", alpha=.5)
grid.add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
plt.figure(figsize=(10,6))

plt.scatter(df.Age[df.Outcome==1],
           df.Pregnancies[df.Outcome==1],c="red")
plt.scatter(df.Age[df.Outcome==0],
           df.Pregnancies[df.Outcome==0],
           c="yellow")
plt.title("femmes enceintes diabitiques")
plt.xlabel("Age")
plt.ylabel("Pregnancies")
plt.legend(["diabitique","Non diabitique"]);

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( df )

# %% [markdown]
# outcome(résultat) et Glucose sont les plus correlés ce qui explique les resultats dans le tableau

# %%
X = df.drop('Outcome',axis=1).values
y = df['Outcome'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=42, stratify=y)
neighbors = np.arange(1,9)
train_accuracy =np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))
for i,k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)

# %%
import random
def loadDataset(filename, split, trainingSet = [], testSet = []):
    with open(filename, "r") as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset)-1):
            for y in range(4):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])

# %%
plt.title('k-NN Nombre variable de voisins')
plt.plot(neighbors, train_accuracy, label='Accuracy:Train')
plt.plot(neighbors, test_accuracy, label='Accuracy:test')
plt.legend()
plt.xlabel('Nombre de voisins')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# pour k=7 Accuracy:train est maximum

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
knn.score(X_test,y_test)
# Out:
# 0.7305194805194806

# %%
y_pred = knn.predict(X_test)
confusion_matrix(y_test,y_pred)
# Out:
# array([[165,  36],
#        [ 47,  60]])

# %%
from sklearn.metrics import roc_auc_score
y_pred_proba = knn.predict_proba(X_test)[:,1]
roc_auc_score(y_test,y_pred_proba)
# Out:
# 0.7345050448691124
